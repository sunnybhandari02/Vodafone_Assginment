# %% [markdown]
# <h1><center>***** Super Store Data Analysis *****</center></h1>

# %% [markdown]
# Name :- Sunny Bhandari
#
# TE E&TC

# %% [markdown]
# # Task 1 :- Identifying and importing essential libraries

# %%
# Importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Task 2 :- Data loading and overview

# %%
# Loading the dataset
df = pd.read_excel('Superstore.xls')

# %%
# displaying first 5 records
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# printing columns name
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# dataframe attributes like count, mean, max, min, standard deviation, etc
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Finding null values in dataset
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Therefor there is no null values in the dataset.

# %% [markdown]
# # Task 3 :- Find out the per unit price from the data

# %%
# Convert date time field into pandas time object
df['Order Date'] = df['Order Date'].dt.strftime('%Y/%m/%d')
df['Ship Date'] = df['Ship Date'].dt.strftime('%Y/%m/%d')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
# creating a columns of price per unit from the data
df['Price Per Unit'] = df['Sales'] / df['Quantity']

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Task 4 :- Find out the monthly revenue and analyze the findings

# %%
# Creating a column with Year and month field only
df['year_month'] = pd.to_datetime(df['Order Date']).dt.to_period('M')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
# Plotting a bar graph for checking monthly sales
plt.figure(figsize=(50,12))
t = df.groupby(['year_month'])['Sales'].sum()
ax = sns.barplot(data = pd.DataFrame(t).transpose())
ax.set(xlabel= "year_month", ylabel="Sales")
# Out:
# [Text(0, 0.5, 'Sales'), Text(0.5, 0, 'year_month')]

# %% [markdown]
# From the above plot we found that Sales were maximum on "2017-11" and minimum on "2014-02".

# %% [markdown]
# # Task 5 :- Find out the yearly revenue and analyze the findings

# %%
# creating a column with year field
df['year'] = pd.to_datetime(df['Order Date']).dt.to_period('Y')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# ...

# %%
df.groupby('year')['Sales'].agg(['sum']).plot.bar()

# %% [markdown]
# From the above bar plot, we found that sales of the store has increased ever year.

# %% [markdown]
# # Task 6 :- Finding out the monthly growth rate and analyse the findings

# %%
# Creating a column for month.
df['month'] = pd.DatetimeIndex(df['Order Date']).month

# %%
# Checking monthly growth rate.
df.groupby('month')['Sales'].agg(['sum']).plot.bar()

# %% [markdown]
# From the above bar plot, we found that sales were very high in the last months of the year.

# %% [markdown]
# # Task 7 :- Finding out the most and least sold product id

# %%
# Creating a new dataset including the product ids and total quantities sold for that id
df1 = pd.DataFrame(df[['Product ID','Quantity']])
df1.head()
# Out:
#         Product ID  Quantity
# 0  FUR-BO-10001798         2
# 1  FUR-CH-10000454         3
# 2  OFF-LA-10000240         2
# 3  FUR-TA-10000577         5
# 4  OFF-ST-10000760         2

# %%
df1['Product ID'].nunique()
# Out:
# 1862

# %%
# Finding out the most sold product from the created dataset
df1=df1['Product ID'].value_counts()
df1
# Out:
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10001146    15
# TEC-AC-10003628    15
#                    ..
# OFF-LA-10003388     1
# TEC-MA-10003673     1
# TEC-PH-10002817     1
# OFF-AP-10000326     1
# FUR-FU-10003095     1
# Name: Product ID, Length: 1862, dtype: int64

# %%
df1.shape
# Out:
# (1862,)

# %% [markdown]
# Therefor most sold product is Product ID :- "OFF-PA-10001970" and least sold product is Product ID:- "FUR-FU-10003095 "

# %% [markdown]
# # Task 8 :- Finding out the customer who bought most and least from us in
# # terms of quantity

# %%
# Creating a dataset containing name and quantities bought
df2 = pd.DataFrame(df[['Customer Name','Quantity']])
df2.head()
# Out:
#      Customer Name  Quantity
# 0      Claire Gute         2
# 1      Claire Gute         3
# 2  Darrin Van Huff         2
# 3   Sean O'Donnell         5
# 4   Sean O'Donnell         2

# %%
df2.nunique()
# Out:
# Customer Name    793
# Quantity          14
# dtype: int64

# %%
df2['Customer Name'].value_counts()
# Out:
# William Brown        37
# Paul Prost           34
# John Lee             34
# Matt Abelman         34
# Seth Vernon          32
#                      ..
# Lela Donovan          1
# Jocasta Rupert        1
# Anthony O'Donnell     1
# Carl Jackson          1
# Ricardo Emerson       1
# Name: Customer Name, Length: 793, dtype: int64

# %%
# Finding out the customer name and quantity, who bought maximum in quantity
df.groupby(["Customer Name"]).sum().sort_values("Quantity", ascending=False)
# Out:
#                    Row ID  Postal Code     Sales  Quantity  Discount  \
# Customer Name
# Jonathan Doherty   158582      1141398  7610.864       150       2.4
# William Brown      212661      2700341  6160.102       146       7.6
# John Lee           186361      1808244  9799.923       143       3.0
# Paul Prost         141723      1369750  7252.608       138       3.7
# Steven Cartwright  110588      1778781  5226.210       133       3.9
# ...                   ...          ...       ...       ...       ...
# Thais Sissman        3572       117197     4.833         4       1.4
# Roland Murray        7471        20022    98.350         4       0.0
# Lela Donovan         6506        60653     5.304         3       0.2
# Jocasta Rupert       1261        32216   863.880         3       0.2
# Anthony O'Donnell    6134        90045   161.280         2       0.2
#
#                       Profit  Price Per Unit  month
# Customer Name
# Jonathan Doherty   1050.2668        1577.690    224
# ...

# %% [markdown]
#  Therefor "Jonathan Doherty" is the customer who bought maximum in quantity and "Anthony O'Donnell" bought least in quantity.

# %% [markdown]
# # Task 9 :- Finding out the customer who bought most and least from us in
# # terms of value

# %%
# Creating a dataset containing name and sales generated by him.
df3 = pd.DataFrame(df[['Customer Name','Sales']])
df3.head()
# Out:
#      Customer Name     Sales
# 0      Claire Gute  261.9600
# 1      Claire Gute  731.9400
# 2  Darrin Van Huff   14.6200
# 3   Sean O'Donnell  957.5775
# 4   Sean O'Donnell   22.3680

# %%
df3['Customer Name'].nunique()
# Out:
# 793

# %%
# Finding out the customer name and sales, who bought maximum in value
df.groupby(["Customer Name"]).sum().sort_values("Sales", ascending=False)
# Out:
#                  Row ID  Postal Code      Sales  Quantity  Discount  \
# Customer Name
# Sean Miller       77545       482091  25043.050        50       3.7
# Tamara Chand      75386       586036  19052.218        42       1.4
# Raymond Buch      69857       914035  15117.339        71       1.7
# Tom Ashbrook      48932       375032  14595.620        36       0.8
# Adrian Barton    130088      1359311  14473.571        73       4.8
# ...                 ...          ...        ...       ...       ...
# Roy Skaria        28004       124322     22.328        10       0.2
# Mitch Gastineau   11579        64432     16.739         8       0.9
# Carl Jackson       8667        19140     16.520         5       0.2
# Lela Donovan       6506        60653      5.304         3       0.2
# Thais Sissman      3572       117197      4.833         4       1.4
#
#                     Profit  Price Per Unit  month
# Customer Name
# Sean Miller     -1980.7393        4355.421     90
# ...

# %% [markdown]
# Therefore, Customer name :- "Sean Miller" has bought most from us in terms of Value and "Thais Sissman" has bought least.

# %% [markdown]
# # Task 10 :- Finding out the majority and minority customer cities on basis of

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
# a.) On the basis of number of customers
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Romeoville         1
# Ormond Beach       1
# Waukesha           1
# Manhattan          1
# Elyria             1
# Name: City, Length: 531, dtype: int64

# %% [markdown]
# Therefor majority customer city is "New York City" on the basis of number of customers and minority customer city is "Tinley Park"

# %%
# b.) On the basis of Sales Value
df.groupby(["City"]).sum().sort_values("Sales", ascending=False)
# Out:
#                 Row ID  Postal Code       Sales  Quantity  Discount  \
# City
# New York City  4450928      9168909  256368.161      3417      51.4
# Los Angeles    3785302     67252887  175851.341      2879      55.5
# Seattle        2199185     41989758  119540.742      1590      27.8
# San Francisco  2462471     47998395  112669.092      1935      34.0
# Philadelphia   2531454     10275302  109077.013      1981     175.5
# ...                ...          ...         ...       ...       ...
# Ormond Beach      2121        32174       2.808         3       0.7
# Pensacola         4879        32503       2.214         3       0.7
# Jupiter           5441        33458       2.064         1       0.2
# Elyria            8716        44035       1.824         1       0.7
# Abilene           6990        79605       1.392         2       0.8
#
#                    Profit  Price Per Unit  month
# City
# New York City  62036.9837       69570.037   7390
# ...

# %% [markdown]
# Therefore, on the basis of Sales, the majority customer city is "New York City" and minority customer city is "Abilene"

# %%
# c.) On the basis of number of Quantity sold
df.groupby(["City"]).sum().sort_values("Quantity", ascending=False)
# Out:
#                 Row ID  Postal Code       Sales  Quantity  Discount  \
# City
# New York City  4450928      9168909  256368.161      3417      51.4
# Los Angeles    3785302     67252887  175851.341      2879      55.5
# Philadelphia   2531454     10275302  109077.013      1981     175.5
# San Francisco  2462471     47998395  112669.092      1935      34.0
# Seattle        2199185     41989758  119540.742      1590      27.8
# ...                ...          ...         ...       ...       ...
# Iowa City         4190        52240       9.990         1       0.0
# Port Orange       1893        32127       7.824         1       0.2
# Lindenhurst        471        11757      55.480         1       0.0
# Littleton         2226        80122      72.294         1       0.7
# Elyria            8716        44035       1.824         1       0.7
#
#                    Profit  Price Per Unit  month
# City
# New York City  62036.9837       69570.037   7390
# ...

# %% [markdown]
# Therefore, on the basis of No. of quantity sold, the majority customer city is "New York City" and minority customer city is "Elyria".

# %% [markdown]
# # Task 11 :- Find out the most and least sold product category from the store

# %%
# a.) Value based
t = df.groupby(['Category'])['Sales'].sum()
ax = sns.barplot(data = pd.DataFrame(t).transpose())
ax.set(xlabel= "Category", ylabel="Sales")
# Out:
# [Text(0, 0.5, 'Sales'), Text(0.5, 0, 'Category')]

# %% [markdown]
# Therefore, most sold product category is "Technology" and least sold product category is "Office Supplies Category".

# %%
# b.) Quantity based
t = df.groupby(['Category'])['Quantity'].sum()
ax = sns.barplot(data = pd.DataFrame(t).transpose())
ax.set(xlabel= "Category", ylabel="Quantity")
# Out:
# [Text(0, 0.5, 'Quantity'), Text(0.5, 0, 'Category')]

# %% [markdown]
# Therefore, most sold product category on the basis of quantity is "Office Supplies Category" and least sold category is "Technology".

# %% [markdown]
# # Task 12 :- Find out the most and least sold product sub category from the
# # store

# %%
# a.) Value Based
plt.figure(figsize=(20,12))
t = df.groupby(['Sub-Category'])['Sales'].sum()
ax = sns.barplot(data = pd.DataFrame(t).transpose())
ax.set(xlabel= "Sub-Category", ylabel="Sales")
# Out:
# [Text(0, 0.5, 'Sales'), Text(0.5, 0, 'Sub-Category')]

# %% [markdown]
# Therefore, most sold product sub category are "Chairs" and "Phones" and least sold product sub category is "Fastners".

# %%
# b.) Quantity Based
plt.figure(figsize=(20,12))
t = df.groupby(['Sub-Category'])['Quantity'].sum()
ax = sns.barplot(data = pd.DataFrame(t).transpose())
ax.set(xlabel= "Sub-Category", ylabel="Quantity")
# Out:
# [Text(0, 0.5, 'Quantity'), Text(0.5, 0, 'Sub-Category')]

# %% [markdown]
# Therefore, most sold product sub category is "Binders" and least sold product sub category is "Copiers".
